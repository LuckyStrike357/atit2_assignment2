# %%
import numpy as np 
import pandas as pd 
from sklearn import preprocessing
import matplotlib.pyplot as plt 
import seaborn as sns
from scipy.stats import norm 

plt.rcParams['figure.figsize'] = [15, 8]

# %%
# read in the cleaned csv dataset 
sf_df = pd.read_csv("./Building_Permits_Clean.csv")

# %%
# rename columns to make it useable for plot scatter 
sf_df.rename(columns={"Permit Type": "Permit_type", 
                                  "Street Number":"Street_number", 
                                  "Number of Existing Stories": "Nr_of_existing_stories"
                                  "Estimated Cose": "Estimated_cost"
                                  "Revised Cost": "Revised_cost"}, inplace=True)

#sf_df.rename(columns = {"Permit Type": "Permit_type", 
                                 # "Street Number":"Street_number", 
                                  #"Number of Existing Stories": "Nr_of_existing_stories"
                                  #"Estimated Cose": "Estimated_cost"
                                  #"Revised Cost": "Revised_cost"})
# Out:
#   File "<ipython-input-24-96b4b7a307f1>", line 5
#     "Estimated Cose": "Estimated_cost"
#                     ^
# SyntaxError: invalid syntax

# %%
sf_df.shape
# Out:
# (143814, 24)

# %%
sf_df.head(5)
# Out:
#    Unnamed: 0  Permit Type Permit Creation Date Block  Lot  Street Number  \
# 0           0            4           05/06/2015  0326  023            140
# 1           1            4           04/19/2016  0306  007            440
# 2           3            8           11/07/2016  0156  011           1230
# 3           4            6           11/28/2016  0342  001            950
# 4           5            8           06/14/2017  4105  009            800
#
#   Street Name Street Suffix Current Status Current Status Date  ...  \
# 0       Ellis            St        expired          12/21/2017  ...
# 1       Geary            St         issued          08/03/2017  ...
# 2     Pacific            Av       complete          07/24/2017  ...
# 3      Market            St         issued          12/01/2017  ...
# 4     Indiana            St         issued          07/06/2017  ...
#
#   Permit Expiration Date Estimated Cost Revised Cost         Existing Use  \
# 0             11/03/2016         4000.0       4000.0  tourist hotel/motel
# 1             12/03/2017            1.0        500.0  tourist hotel/motel
# 2             07/13/2018         2000.0       2000.0    1 family dwelling
# 3             12/01/2018       100000.0     100000.0         retail sales
# 4             07/01/2018         4000.0       4000.0           apartments
#
#   Existing Units  Plansets  Existing Construction Type Supervisor District  \
# 0          143.0       2.0                         3.0                 3.0
# 1            1.0       2.0                         3.0                 3.0
# 2            1.0       2.0                         5.0                 3.0
# 3            1.0       2.0                         3.0                 6.0
# 4          326.0       2.0                         1.0                10.0
#
#    Neighborhoods - Analysis Boundaries  Zipcode
# 0                           Tenderloin  94102.0
# 1                           Tenderloin  94102.0
# 2                             Nob Hill  94109.0
# 3                           Tenderloin  94102.0
# 4                         Potrero Hill  94107.0
#
# [5 rows x 24 columns]

# %%
correlation_matrix = sf_df.corr().round(2)
sns.heatmap(data=correlation_matrix, annot=True)

# %%
plt.scatter(sf_df.rm, sf_df.medv)
plt.xlabel('rooms')
plt.ylabel('price')

# %%
corrmat = sf_df.corr() 
  
f, ax = plt.subplots(figsize =(9, 8)) 
sns.heatmap(corrmat, ax = ax, cmap ="YlGnBu", linewidths = 0.1)
